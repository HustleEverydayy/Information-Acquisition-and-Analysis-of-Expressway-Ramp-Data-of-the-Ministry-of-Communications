# %%
import pandas as pd

SrcDir = "../SRC/"
SrcFile = 'part-r-00000_TDCS_201611_201910_03F1779S_03F2129S_G8_Key_TotalTime_TimeIntervals_TFCFLength_ClassFrequency_1_0'
SrcLocation = SrcDir +SrcFile

#pd.read_csv(SrcLocation)
#pd.read_csv(SrcLocation,sep='\#\#')
#pd.read_csv(SrcLocation,sep='\#\#|\t')
data = pd.read_csv(SrcLocation,sep='\#\#|\t', header=None)
# Out:
# C:\Users\jdwang\anaconda3\lib\site-packages\ipykernel_launcher.py:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   # Remove the CWD from sys.path while we load stuff.

# %%
data
# Out:
#          0   1                2  3  4  5  \
# 0        0  13   -3-3-2-2-1-1-1  2  2  8
# 1        0  13   -3-3-2-2-1-1-1  2  2  8
# 2        0  13   -3-3-2-2-1-1-1  2  2  8
# 3        0  13   -3-3-2-2-1-1-1  4  4  8
# 4        0  13   -3-3-2-2-1-1-1  3  3  8
# ...     ..  ..              ... .. .. ..
# 220642  23  33  -4-5-2-4-1-1-16  2  2  8
# 220643  23  35  -19-5-3-4-1-1-2  3  3  8
# 220644  23  39  -4-5-2-25-1-1-1  2  2  8
# 220645  23  41  -26-5-2-4-1-1-2  2  2  8
# 220646  23  42  -25-5-3-5-1-1-2  2  2  8
#
#                                                         6
# 0          (2018-01-23_Tue_31#1#1)(2018-07-20_Fri_31#1#1)
# 1          (2018-01-01_Mon_31#1#1)(2018-12-24_Mon_31#1#1)
# 2          (2017-07-24_Mon_31#1#1)(2018-04-01_Sun_31#1#1)
# 3       (2017-03-22_Wed_31#1#1)(2018-05-28_Mon_31#1#1)...
# 4       (2017-08-05_Sat_31#1#1)(2017-12-30_Sat_31#1#1)...
# ...                                                   ...
# ...

# %%
data.columns = ["Hour","TotalTime","TimeIntervals","TF","DF","NumOfGantries","ClassFrequencyDistribution"]

# %%
data
# Out:
#         Hour  TotalTime    TimeIntervals  TF  DF  NumOfGantries  \
# 0          0         13   -3-3-2-2-1-1-1   2   2              8
# 1          0         13   -3-3-2-2-1-1-1   2   2              8
# 2          0         13   -3-3-2-2-1-1-1   2   2              8
# 3          0         13   -3-3-2-2-1-1-1   4   4              8
# 4          0         13   -3-3-2-2-1-1-1   3   3              8
# ...      ...        ...              ...  ..  ..            ...
# 220642    23         33  -4-5-2-4-1-1-16   2   2              8
# 220643    23         35  -19-5-3-4-1-1-2   3   3              8
# 220644    23         39  -4-5-2-25-1-1-1   2   2              8
# 220645    23         41  -26-5-2-4-1-1-2   2   2              8
# 220646    23         42  -25-5-3-5-1-1-2   2   2              8
#
#                                ClassFrequencyDistribution
# 0          (2018-01-23_Tue_31#1#1)(2018-07-20_Fri_31#1#1)
# 1          (2018-01-01_Mon_31#1#1)(2018-12-24_Mon_31#1#1)
# ...

# %%
data_0 = data[data['Hour']==0]
data_0
# Out:
#       Hour  TotalTime    TimeIntervals  TF  DF  NumOfGantries  \
# 0        0         13   -3-3-2-2-1-1-1   2   2              8
# 1        0         13   -3-3-2-2-1-1-1   2   2              8
# 2        0         13   -3-3-2-2-1-1-1   2   2              8
# 3        0         13   -3-3-2-2-1-1-1   4   4              8
# 4        0         13   -3-3-2-2-1-1-1   3   3              8
# ...    ...        ...              ...  ..  ..            ...
# 3631     0         29  -13-5-3-4-1-1-2   2   2              8
# 3632     0         29   -7-7-4-6-1-2-2   2   2              8
# 3633     0         43  -5-28-3-3-1-1-2   3   2              8
# 3634     0         56  -41-5-3-4-1-1-1   2   2              8
# 3635     0         80  -66-4-3-4-0-1-2   2   2              8
#
#                              ClassFrequencyDistribution
# 0        (2018-01-23_Tue_31#1#1)(2018-07-20_Fri_31#1#1)
# 1        (2018-01-01_Mon_31#1#1)(2018-12-24_Mon_31#1#1)
# ...

# %%
#data_0_13 = data[(data['Hour']==0) & (data['TotalTime']==13)]
#data_0_13
data_0_14 = data[(data['Hour']==0) & (data['TotalTime']==14)]
data_0_14
# Out:
#     Hour  TotalTime   TimeIntervals  TF  DF  NumOfGantries  \
# 14     0         14  -3-3-2-3-1-0-2   4   4              8
# 15     0         14  -3-3-2-3-1-1-1   3   3              8
# 16     0         14  -3-4-1-3-1-0-2   3   3              8
# 17     0         14  -3-4-1-3-1-1-1   3   3              8
# 18     0         14  -3-4-1-3-1-1-1   2   2              8
# 19     0         14  -3-4-1-3-1-1-1   2   2              8
# 20     0         14  -3-4-1-3-1-1-1   4   4              8
# 21     0         14  -3-4-1-4-0-1-1   2   2              8
# 22     0         14  -3-4-2-2-1-1-1   2   2              8
# 23     0         14  -3-4-2-3-0-1-1   5   4              8
# 24     0         14  -3-4-2-3-0-1-1   6   6              8
# 25     0         14  -4-3-1-3-1-0-2   2   2              8
# 26     0         14  -4-3-1-3-1-0-2   2   2              8
# 27     0         14  -4-3-1-3-1-1-1   2   2              8
# 28     0         14  -4-3-2-2-1-1-1   2   2              8
# ...

# %%
data["TotalTime"].max()
# Out:
# 125

# %%
data["TotalTime"].min()
# Out:
# 12

# %%
data.describe()
# Out:
#                 Hour      TotalTime             TF             DF  \
# count  220647.000000  220647.000000  220647.000000  220647.000000
# mean       12.279170      22.648756      33.565646      28.963217
# std         5.301006       5.438895      85.754851      66.614959
# min         0.000000      12.000000       2.000000       1.000000
# 25%         9.000000      20.000000       3.000000       3.000000
# 50%        11.000000      22.000000       7.000000       7.000000
# 75%        17.000000      24.000000      25.000000      23.000000
# max        23.000000     125.000000    1099.000000     701.000000
#
#        NumOfGantries
# count       220647.0
# mean             8.0
# std              0.0
# min              8.0
# 25%              8.0
# 50%              8.0
# 75%              8.0
# max              8.0

# %%
data_TF_Max = data[data['TF']==1099]
data_TF_Max
# Out:
#        Hour  TotalTime   TimeIntervals    TF   DF  NumOfGantries  \
# 97495    11         19  -4-5-2-4-1-1-2  1099  695              8
#
#                               ClassFrequencyDistribution
# 97495  (2016-11-01_Tue_31#1#1)(2016-11-02_Wed_31#1#1)...

# %%
# Pandas vs. GroupBy
#https://ithelp.ithome.com.tw/articles/10194027
data.groupby('TotalTime').sum()
# Out:
#             Hour     TF     DF  NumOfGantries
# TotalTime
# 12           130     26     21             80
# 13           522    145    133            416
# 14          2553    612    570           1680
# 15         12827   5761   5448           8688
# 16         39243  34559  32831          26632
# ...          ...    ...    ...            ...
# 118           11      3      3              8
# 119           17      2      2              8
# 120           12      2      2              8
# 121           25      7      3             16
# 125           13      2      2              8
#
# [110 rows x 4 columns]

# %%
#data[['Hour','TotalTime','TF']].groupby(['Hour','TotalTime']).sum()
data[['TotalTime','TF']].groupby(['TotalTime']).sum()
# Out:
#   File "<ipython-input-35-d7b11b0e516d>", line 2
#     data[['TotalTime','TF']].groupby(['TotalTime'].sum()
#                                                         ^
# SyntaxError: unexpected EOF while parsing

# %%
data[['Hour','TotalTime']]
#data_Partial
#data["Hour","TotalTime","TimeIntervals","TF"].groupby(['TotalTime','Hour']).sum('TF')
# Out:
#         Hour  TotalTime
# 0          0         13
# 1          0         13
# 2          0         13
# 3          0         13
# 4          0         13
# ...      ...        ...
# 220642    23         33
# 220643    23         35
# 220644    23         39
# 220645    23         41
# 220646    23         42
#
# [220647 rows x 2 columns]

# %%
TotalTimeDistribution = data.groupby(['Hour','TotalTime'])
TotalTimeDistribution.size()
# Out:
# Hour  TotalTime
# 0     13            14
#       14            27
#       15           110
#       16           176
#       17           299
#                   ...
# 23    33             1
#       35             1
#       39             1
#       41             1
#       42             1
# Length: 1104, dtype: int64

# %%
TotalTimeDistribution['Hour'].size()
# Out:
# Hour  TotalTime
# 0     13            14
#       14            27
#       15           110
#       16           176
#       17           299
#                   ...
# 23    33             1
#       35             1
#       39             1
#       41             1
#       42             1
# Name: Hour, Length: 1104, dtype: int64

# %%
data.groupby(['Hour','TotalTime']).sum().sort_values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-fa9ac4360536> in <module>
# ----> 1 data.groupby(['Hour','TotalTime']).sum().sort_values()
#
# TypeError: sort_values() missing 1 required positional argument: 'by'
