# %%
# jdwang@asia.edu.tw Jing-Doo Wang
# 2020/11/3

# %%
import pandas as pd

SrcDir = "../SRC/"
SrcFile = 'part-r-00000_TDCS_201611_201910_03F1779S_03F2129S_G8_Key_TotalTime_TimeIntervals_TFCFLength_ClassFrequency_1_0'
SrcLocation = SrcDir +SrcFile

#pd.read_csv(SrcLocation)
#pd.read_csv(SrcLocation,sep='\#\#')
#pd.read_csv(SrcLocation,sep='\#\#|\t')
TDCS_MRP_data = pd.read_csv(SrcLocation,sep='\#\#|\t', header=None)

TDCS_MRP_data
# Out:
# C:\Users\jdwang\anaconda3\lib\site-packages\ipykernel_launcher.py:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   # Remove the CWD from sys.path while we load stuff.
#          0   1                2  3  4  5  \
# 0        0  13   -3-3-2-2-1-1-1  2  2  8
# 1        0  13   -3-3-2-2-1-1-1  2  2  8
# 2        0  13   -3-3-2-2-1-1-1  2  2  8
# 3        0  13   -3-3-2-2-1-1-1  4  4  8
# 4        0  13   -3-3-2-2-1-1-1  3  3  8
# ...     ..  ..              ... .. .. ..
# 220642  23  33  -4-5-2-4-1-1-16  2  2  8
# 220643  23  35  -19-5-3-4-1-1-2  3  3  8
# 220644  23  39  -4-5-2-25-1-1-1  2  2  8
# 220645  23  41  -26-5-2-4-1-1-2  2  2  8
# 220646  23  42  -25-5-3-5-1-1-2  2  2  8
#
#                                                         6
# ...

# %%
TDCS_MRP_data.columns = ["Hour","TotalTravelTime","TravelTimeIntervals","TF","DF","NumOfGantries","ClassFrequencyDistribution"]
TDCS_MRP_data
# Out:
#         Hour  TotalTravelTime TravelTimeIntervals  TF  DF  NumOfGantries  \
# 0          0               13      -3-3-2-2-1-1-1   2   2              8
# 1          0               13      -3-3-2-2-1-1-1   2   2              8
# 2          0               13      -3-3-2-2-1-1-1   2   2              8
# 3          0               13      -3-3-2-2-1-1-1   4   4              8
# 4          0               13      -3-3-2-2-1-1-1   3   3              8
# ...      ...              ...                 ...  ..  ..            ...
# 220642    23               33     -4-5-2-4-1-1-16   2   2              8
# 220643    23               35     -19-5-3-4-1-1-2   3   3              8
# 220644    23               39     -4-5-2-25-1-1-1   2   2              8
# 220645    23               41     -26-5-2-4-1-1-2   2   2              8
# 220646    23               42     -25-5-3-5-1-1-2   2   2              8
#
#                                ClassFrequencyDistribution
# ...

# %%
TDCS_MRP_data['TotalTravelTime'].describe()
# Out:
# count    220647.000000
# mean         22.648756
# std           5.438895
# min          12.000000
# 25%          20.000000
# 50%          22.000000
# 75%          24.000000
# max         125.000000
# Name: TotalTravelTime, dtype: float64

# %%
print(len(pd.unique(TDCS_MRP_data['TravelTimeIntervals'])))
# Out:
# 12068

# %%
TDCS_MRP_data_MinTotalTravelTime = TDCS_MRP_data[ TDCS_MRP_data['TotalTravelTime'] == 12 ]
print(len(pd.unique(TDCS_MRP_data_MinTotalTravelTime['TravelTimeIntervals'])))
TDCS_MRP_data_MinTotalTravelTime
# Out:
# 3
#         Hour  TotalTravelTime TravelTimeIntervals  TF  DF  NumOfGantries  \
# 3636       1               12      -3-3-2-2-1-0-1   2   1              8
# 6568       2               12      -3-3-1-3-0-1-1   5   2              8
# 8993       3               12      -3-3-1-3-0-1-1   2   2              8
# 14413      5               12      -3-3-1-3-0-1-1   4   4              8
# 14414      5               12      -3-3-1-3-0-1-1   2   2              8
# 211128    22               12      -3-2-2-2-1-1-1   2   2              8
# 216320    23               12      -3-3-1-3-0-1-1   2   2              8
# 216321    23               12      -3-3-1-3-0-1-1   3   2              8
# 216322    23               12      -3-3-1-3-0-1-1   2   2              8
# 216323    23               12      -3-3-1-3-0-1-1   2   2              8
#
#                                ClassFrequencyDistribution
# 3636                              (2019-09-08_Sun_31#2#2)
# ...

# %%
TDCS_MRP_data_MinTotalTravelTime = TDCS_MRP_data[ TDCS_MRP_data['TotalTravelTime'] == 125 ]
print(len(pd.unique(TDCS_MRP_data_MinTotalTravelTime['TravelTimeIntervals'])))
TDCS_MRP_data_MinTotalTravelTime
# Out:
# 1
#         Hour  TotalTravelTime TravelTimeIntervals  TF  DF  NumOfGantries  \
# 121787    13              125    -108-6-3-4-1-1-2   2   2              8
#
#                             ClassFrequencyDistribution
# 121787  (2017-05-27_Sat_32#1#1)(2019-02-14_Thu_31#1#1)

# %%
TDCS_MRP_data_MinTotalTravelTime = TDCS_MRP_data[ TDCS_MRP_data['TotalTravelTime'] == 23 ]
print(len(pd.unique(TDCS_MRP_data_MinTotalTravelTime['TravelTimeIntervals'])))
TDCS_MRP_data_MinTotalTravelTime
# Out:
# 314
#         Hour  TotalTravelTime TravelTimeIntervals  TF  DF  NumOfGantries  \
# 3176       0               23      -5-5-3-5-1-1-3   2   2              8
# 3177       0               23      -5-5-3-5-1-2-2   4   4              8
# 3178       0               23      -5-5-3-5-1-2-2   4   4              8
# 3179       0               23      -5-5-3-5-1-2-2   5   5              8
# 3180       0               23      -5-5-3-5-1-2-2   2   2              8
# ...      ...              ...                 ...  ..  ..            ...
# 220347    23               23      -6-6-3-4-1-1-2   2   2              8
# 220348    23               23      -6-6-3-4-1-1-2   2   2              8
# 220349    23               23      -6-6-3-4-1-2-1   3   3              8
# 220350    23               23      -8-5-3-4-0-1-2   2   1              8
# 220351    23               23      -8-5-3-4-1-1-1   3   2              8
#
#                                ClassFrequencyDistribution
# ...

# %%
TDCS_MRP_data_MinTotalTravelTime = TDCS_MRP_data[ TDCS_MRP_data['TotalTravelTime'] == 22 ]
print(len(pd.unique(TDCS_MRP_data_MinTotalTravelTime['TravelTimeIntervals'])))
TDCS_MRP_data_MinTotalTravelTime
# Out:
# 253
#         Hour  TotalTravelTime TravelTimeIntervals  TF  DF  NumOfGantries  \
# 2838       0               22      -4-5-3-5-1-2-2   2   2              8
# 2839       0               22      -4-6-3-5-1-1-2   2   2              8
# 2840       0               22      -5-5-3-4-1-2-2   4   4              8
# 2841       0               22      -5-5-3-4-1-2-2   3   3              8
# 2842       0               22      -5-5-3-4-1-2-2   9   9              8
# ...      ...              ...                 ...  ..  ..            ...
# 220081    23               22      -6-5-3-4-1-2-1   2   2              8
# 220082    23               22      -6-5-3-4-1-2-1   5   5              8
# 220083    23               22      -6-5-3-4-1-2-1   2   2              8
# 220084    23               22      -6-5-3-4-1-2-1   3   3              8
# 220085    23               22      -7-5-2-4-1-1-2   2   2              8
#
#                                ClassFrequencyDistribution
# ...

# %%
TDCS_MRP_data_OneHour = TDCS_MRP_data[(TDCS_MRP_data['Hour'] == 0 ) & (TDCS_MRP_data['TotalTravelTime'] == 13 )]
TDCS_MRP_data_OneHour
# Out:
#     Hour  TotalTravelTime TravelTimeIntervals  TF  DF  NumOfGantries  \
# 0      0               13      -3-3-2-2-1-1-1   2   2              8
# 1      0               13      -3-3-2-2-1-1-1   2   2              8
# 2      0               13      -3-3-2-2-1-1-1   2   2              8
# 3      0               13      -3-3-2-2-1-1-1   4   4              8
# 4      0               13      -3-3-2-2-1-1-1   3   3              8
# 5      0               13      -3-3-2-2-1-1-1   2   2              8
# 6      0               13      -3-3-2-3-0-1-1   3   3              8
# 7      0               13      -3-3-2-3-0-1-1   2   2              8
# 8      0               13      -3-3-2-3-0-1-1   3   2              8
# 9      0               13      -3-3-2-3-0-1-1   3   3              8
# 10     0               13      -3-3-2-3-0-1-1   2   2              8
# 11     0               13      -3-3-2-3-0-1-1   2   2              8
# 12     0               13      -3-4-1-3-0-1-1   2   2              8
# ...

# %%
TDCS_MRP_data_MinTotalTravelTime = TDCS_MRP_data[ TDCS_MRP_data['TotalTravelTime'] == 24 ]
print(len(pd.unique(TDCS_MRP_data_MinTotalTravelTime['TravelTimeIntervals'])))
TDCS_MRP_data_MinTotalTravelTime
# Out:
# 387
#         Hour  TotalTravelTime TravelTimeIntervals  TF  DF  NumOfGantries  \
# 3395       0               24      -5-6-3-5-1-2-2   5   5              8
# 3396       0               24      -5-6-3-5-1-2-2   3   3              8
# 3397       0               24      -5-6-3-5-1-2-2   4   4              8
# 3398       0               24      -5-6-3-5-1-2-2   5   5              8
# 3399       0               24      -5-6-3-5-1-2-2   5   5              8
# ...      ...              ...                 ...  ..  ..            ...
# 220509    23               24      -6-6-3-5-1-1-2   6   6              8
# 220510    23               24      -6-6-3-5-1-1-2   3   3              8
# 220511    23               24      -8-5-3-4-1-1-2   5   1              8
# 220512    23               24      -8-5-3-4-1-1-2   6   1              8
# 220513    23               24      -8-5-4-4-0-2-1   2   1              8
#
#                                ClassFrequencyDistribution
# ...

# %%
TDCS_MRP_data_MinTotalTravelTime = TDCS_MRP_data[ TDCS_MRP_data['TotalTravelTime'] == 25 ]
print(len(pd.unique(TDCS_MRP_data_MinTotalTravelTime['TravelTimeIntervals'])))
TDCS_MRP_data_MinTotalTravelTime
# Out:
# 472
#         Hour  TotalTravelTime TravelTimeIntervals  TF  DF  NumOfGantries  \
# 3523       0               25      -5-6-4-5-1-2-2   2   2              8
# 3524       0               25      -5-7-3-5-1-2-2   3   3              8
# 3525       0               25      -5-7-3-5-1-2-2   2   2              8
# 3526       0               25      -6-5-4-5-1-2-2   2   2              8
# 3527       0               25      -6-5-4-5-1-2-2   2   2              8
# ...      ...              ...                 ...  ..  ..            ...
# 220579    23               25      -6-6-3-6-1-1-2   6   6              8
# 220580    23               25      -6-6-4-5-1-1-2   2   2              8
# 220581    23               25      -6-6-4-5-1-1-2   2   2              8
# 220582    23               25      -6-6-4-5-1-1-2   2   2              8
# 220583    23               25      -6-6-4-5-1-1-2   2   2              8
#
#                                ClassFrequencyDistribution
# ...
